# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime 
import numpy as np

# %% [markdown]
# ## First read in weather data from csv file.

# %%
df_weather = pd.read_csv('weather_data/Weather.csv')

# %% [markdown]
# ## Keep only the columns that we need

# %%
df_weather = df_weather.drop(columns=['tempi', 'dewpti', 'wspdm', 'wgustm', 'wgusti', 'wdird', 'wdire', 'vism',
                          'pressurei', 'windchillm', 'windchilli', 'heatindexm', 'heatindexi', 'precipi', 'icon'])

# %%
df_weather.head()
# Out:
#        pickup_datetime  tempm  dewptm   hum  wspdi  visi  pressurem  precipm  \
# 0  2015-12-31 00:15:00    7.8     6.1  89.0    4.6   2.5     1018.2      0.5
# 1  2015-12-31 00:42:00    7.8     6.1  89.0    4.6   4.0     1017.8      0.8
# 2  2015-12-31 00:51:00    7.8     6.1  89.0    3.5   5.0     1017.0      0.8
# 3  2015-12-31 01:51:00    7.2     5.6  90.0    4.6   8.0     1016.5      0.3
# 4  2015-12-31 02:51:00    7.2     5.6  90.0    0.0   8.0     1016.7      NaN
#
#         conds  fog  rain  snow  hail  thunder  tornado
# 0  Light Rain    0     1     0     0        0        0
# 1    Overcast    0     0     0     0        0        0
# 2    Overcast    0     0     0     0        0        0
# 3    Overcast    0     0     0     0        0        0
# 4    Overcast    0     0     0     0        0        0

# %%
df_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10481 entries, 0 to 10480
# Data columns (total 15 columns):
# pickup_datetime    10481 non-null object
# tempm              10476 non-null float64
# dewptm             10476 non-null float64
# hum                10476 non-null float64
# wspdi              9744 non-null float64
# visi               10236 non-null float64
# pressurem          10242 non-null float64
# precipm            1706 non-null float64
# conds              10481 non-null object
# fog                10481 non-null int64
# rain               10481 non-null int64
# snow               10481 non-null int64
# hail               10481 non-null int64
# thunder            10481 non-null int64
# tornado            10481 non-null int64
# dtypes: float64(7), int64(6), object(2)
# memory usage: 1.2+ MB

# %%
#check if snow and rain happen on the same days
len(df_weather[(df_weather.rain == 1) & (df_weather.snow == 1)])
# Out:
# 0

# %% [markdown]
# ### Manage null values

# %%
df_weather[df_weather.tempm.isnull() == True]
# Out:
#           pickup_datetime  tempm  dewptm  hum  wspdi  visi  pressurem  \
# 2847  2016-04-04 09:00:00    NaN     NaN  NaN    NaN   NaN        NaN
# 3241  2016-04-19 07:00:00    NaN     NaN  NaN    NaN   NaN        NaN
# 3643  2016-05-04 06:00:00    NaN     NaN  NaN    NaN   NaN        NaN
# 5520  2016-07-11 18:00:00    NaN     NaN  NaN    NaN   NaN        NaN
# 8850  2016-11-04 07:00:00    NaN     NaN  NaN    NaN   NaN        NaN
#
#       precipm    conds  fog  rain  snow  hail  thunder  tornado
# 2847      NaN  Unknown    0     0     0     0        0        0
# 3241      NaN  Unknown    0     0     0     0        0        0
# 3643      NaN  Unknown    0     0     0     0        0        0
# 5520      NaN  Unknown    0     0     0     0        0        0
# 8850      NaN  Unknown    0     0     0     0        0        0

# %%
df_weather[df_weather.dewptm.isnull() == True]
# Out:
#           pickup_datetime  tempm  dewptm  hum  wspdi  visi  pressurem  \
# 2847  2016-04-04 09:00:00    NaN     NaN  NaN    NaN   NaN        NaN
# 3241  2016-04-19 07:00:00    NaN     NaN  NaN    NaN   NaN        NaN
# 3643  2016-05-04 06:00:00    NaN     NaN  NaN    NaN   NaN        NaN
# 5520  2016-07-11 18:00:00    NaN     NaN  NaN    NaN   NaN        NaN
# 8850  2016-11-04 07:00:00    NaN     NaN  NaN    NaN   NaN        NaN
#
#       precipm    conds  fog  rain  snow  hail  thunder  tornado
# 2847      NaN  Unknown    0     0     0     0        0        0
# 3241      NaN  Unknown    0     0     0     0        0        0
# 3643      NaN  Unknown    0     0     0     0        0        0
# 5520      NaN  Unknown    0     0     0     0        0        0
# 8850      NaN  Unknown    0     0     0     0        0        0

# %%
df_weather[df_weather.hum.isnull() == True]
# Out:
#           pickup_datetime  tempm  dewptm  hum  wspdi  visi  pressurem  \
# 2847  2016-04-04 09:00:00    NaN     NaN  NaN    NaN   NaN        NaN
# 3241  2016-04-19 07:00:00    NaN     NaN  NaN    NaN   NaN        NaN
# 3643  2016-05-04 06:00:00    NaN     NaN  NaN    NaN   NaN        NaN
# 5520  2016-07-11 18:00:00    NaN     NaN  NaN    NaN   NaN        NaN
# 8850  2016-11-04 07:00:00    NaN     NaN  NaN    NaN   NaN        NaN
#
#       precipm    conds  fog  rain  snow  hail  thunder  tornado
# 2847      NaN  Unknown    0     0     0     0        0        0
# 3241      NaN  Unknown    0     0     0     0        0        0
# 3643      NaN  Unknown    0     0     0     0        0        0
# 5520      NaN  Unknown    0     0     0     0        0        0
# 8850      NaN  Unknown    0     0     0     0        0        0

# %%
df_weather[3240:3245]
# Out:
#           pickup_datetime  tempm  dewptm   hum  wspdi  visi  pressurem  \
# 3240  2016-04-19 06:51:00   17.8     0.0  30.0    6.9  10.0     1013.8
# 3241  2016-04-19 07:00:00    NaN     NaN   NaN    NaN   NaN        NaN
# 3242  2016-04-19 07:51:00   18.3     1.1  32.0    5.8  10.0     1014.5
# 3243  2016-04-19 08:51:00   18.9     4.4  38.0    NaN  10.0     1014.7
# 3244  2016-04-19 10:51:00   20.0     5.0  37.0    9.2  10.0     1015.2
#
#       precipm          conds  fog  rain  snow  hail  thunder  tornado
# 3240      NaN  Mostly Cloudy    0     0     0     0        0        0
# 3241      NaN        Unknown    0     0     0     0        0        0
# 3242      NaN          Clear    0     0     0     0        0        0
# 3243      NaN          Clear    0     0     0     0        0        0
# 3244      NaN  Partly Cloudy    0     0     0     0        0        0

# %% [markdown]
# ### The missing values for tempm, dewptm, and hum all happen at the same instances.  Let's take the average of the values before and after the nan value.

# %%
df_weather['tempm'] = (df_weather.tempm.ffill() + df_weather.tempm.bfill())/2
df_weather['dewptm'] = (df_weather.dewptm.ffill() + df_weather.dewptm.bfill())/2
df_weather['hum'] = (df_weather.hum.ffill() + df_weather.hum.bfill())/2

# %%
df_weather[3240:3245]
# Out:
#           pickup_datetime  tempm  dewptm   hum  wspdi  visi  pressurem  \
# 3240  2016-04-19 06:51:00  17.80    0.00  30.0    6.9  10.0     1013.8
# 3241  2016-04-19 07:00:00  18.05    0.55  31.0    NaN   NaN        NaN
# 3242  2016-04-19 07:51:00  18.30    1.10  32.0    5.8  10.0     1014.5
# 3243  2016-04-19 08:51:00  18.90    4.40  38.0    NaN  10.0     1014.7
# 3244  2016-04-19 10:51:00  20.00    5.00  37.0    9.2  10.0     1015.2
#
#       precipm          conds  fog  rain  snow  hail  thunder  tornado
# 3240      NaN  Mostly Cloudy    0     0     0     0        0        0
# 3241      NaN        Unknown    0     0     0     0        0        0
# 3242      NaN          Clear    0     0     0     0        0        0
# 3243      NaN          Clear    0     0     0     0        0        0
# 3244      NaN  Partly Cloudy    0     0     0     0        0        0

# %%
df_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10481 entries, 0 to 10480
# Data columns (total 15 columns):
# pickup_datetime    10481 non-null object
# tempm              10481 non-null float64
# dewptm             10481 non-null float64
# hum                10481 non-null float64
# wspdi              9744 non-null float64
# visi               10236 non-null float64
# pressurem          10242 non-null float64
# precipm            1706 non-null float64
# conds              10481 non-null object
# fog                10481 non-null int64
# rain               10481 non-null int64
# snow               10481 non-null int64
# hail               10481 non-null int64
# thunder            10481 non-null int64
# tornado            10481 non-null int64
# dtypes: float64(7), int64(6), object(2)
# memory usage: 1.2+ MB

# %%
df_weather.wspdi.describe()
# Out:
# count    9744.000000
# mean        5.410324
# std         3.925301
# min         0.000000
# 25%         3.500000
# 50%         4.600000
# 75%         8.100000
# max        85.200000
# Name: wspdi, dtype: float64

# %%
df_weather[df_weather.wspdi.isnull() == True].head(10)
# Out:
#          pickup_datetime  tempm  dewptm   hum  wspdi  visi  pressurem  \
# 22   2015-12-31 14:51:00    8.9     0.6  56.0    NaN  10.0     1016.7
# 29   2015-12-31 21:51:00    6.1    -3.3  51.0    NaN  10.0     1019.0
# 47   2016-01-01 15:51:00    3.9    -6.7  46.0    NaN  10.0     1014.9
# 53   2016-01-01 21:51:00    1.7    -6.7  54.0    NaN  10.0     1016.6
# 67   2016-01-02 11:51:00   13.9     3.3  49.0    NaN  10.0     1009.2
# 99   2016-01-03 19:51:00    7.8     1.7  66.0    NaN  10.0     1011.9
# 123  2016-01-04 22:51:00   21.0    10.0  49.0    NaN  10.0     1003.1
# 126  2016-01-05 01:51:00   10.0     2.8  61.0    NaN  10.0     1023.0
# 141  2016-01-05 12:51:00    8.3     6.1  86.0    NaN   7.0     1021.7
# 182  2016-01-06 18:51:00   24.4    12.2  46.0    NaN   8.0     1019.1
#
#      precipm          conds  fog  rain  snow  hail  thunder  tornado
# 22       NaN       Overcast    0     0     0     0        0        0
# 29       NaN       Overcast    0     0     0     0        0        0
# 47       NaN       Overcast    0     0     0     0        0        0
# 53       NaN          Clear    0     0     0     0        0        0
# 67       NaN          Clear    0     0     0     0        0        0
# 99       NaN       Overcast    0     0     0     0        0        0
# 123      NaN  Mostly Cloudy    0     0     0     0        0        0
# 126      NaN          Clear    0     0     0     0        0        0
# 141      0.8     Light Rain    0     1     0     0        0        0
# 182      NaN          Clear    0     0     0     0        0        0

# %%
df_weather[122:128]
# Out:
#          pickup_datetime  tempm  dewptm   hum  wspdi  visi  pressurem  \
# 122  2016-01-04 21:51:00   20.6    13.3  63.0    3.5  10.0     1001.9
# 123  2016-01-04 22:51:00   21.0    10.0  49.0    NaN  10.0     1003.1
# 124  2016-01-04 23:51:00   16.7     6.1  50.0    0.0  10.0     1003.7
# 125  2016-01-05 00:51:00   10.0     0.0  50.0    3.5  10.0     1023.7
# 126  2016-01-05 01:51:00   10.0     2.8  61.0    NaN  10.0     1023.0
# 127  2016-01-05 02:51:00   10.0     0.6  52.0    5.8  10.0     1022.4
#
#      precipm             conds  fog  rain  snow  hail  thunder  tornado
# 122      NaN  Scattered Clouds    0     0     0     0        0        0
# 123      NaN     Mostly Cloudy    0     0     0     0        0        0
# 124      NaN     Mostly Cloudy    0     0     0     0        0        0
# 125      NaN             Clear    0     0     0     0        0        0
# 126      NaN             Clear    0     0     0     0        0        0
# 127      NaN     Mostly Cloudy    0     0     0     0        0        0

# %% [markdown]
# ### Since some of the wspdi values are already 0, it doesn't make sense to fill in the nan values with 0.  Use forward fill instead.

# %%
df_weather.wspdi.ffill(inplace = True)

# %%
df_weather[122:125]
# Out:
#          pickup_datetime  tempm  dewptm   hum  wspdi  visi  pressurem  \
# 122  2016-01-04 21:51:00   20.6    13.3  63.0    3.5  10.0     1001.9
# 123  2016-01-04 22:51:00   21.0    10.0  49.0    3.5  10.0     1003.1
# 124  2016-01-04 23:51:00   16.7     6.1  50.0    0.0  10.0     1003.7
#
#      precipm             conds  fog  rain  snow  hail  thunder  tornado
# 122      NaN  Scattered Clouds    0     0     0     0        0        0
# 123      NaN     Mostly Cloudy    0     0     0     0        0        0
# 124      NaN     Mostly Cloudy    0     0     0     0        0        0

# %%
df_weather.visi.count()
# Out:
# 10236

# %%
df_weather[df_weather.visi.isnull() == True].tail()
# Out:
#           pickup_datetime  tempm  dewptm   hum  wspdi  visi  pressurem  \
# 7308  2016-09-12 11:51:00   4.00   -7.00  45.0    6.9   NaN        NaN
# 7309  2016-09-12 12:51:00   5.00   -7.00  42.0    6.9   NaN        NaN
# 7310  2016-09-12 13:51:00   4.00  -10.00  36.0    6.9   NaN        NaN
# 8850  2016-11-04 07:00:00   8.05    1.15  62.0    6.9   NaN        NaN
# 9048  2016-11-12 00:52:00  -1.70   -8.90  58.0    0.0   NaN     1031.5
#
#       precipm    conds  fog  rain  snow  hail  thunder  tornado
# 7308      NaN  Unknown    0     0     0     0        0        0
# 7309      NaN  Unknown    0     0     0     0        0        0
# 7310      NaN  Unknown    0     0     0     0        0        0
# 8850      NaN  Unknown    0     0     0     0        0        0
# 9048      NaN  Unknown    0     0     0     0        0        0

# %%
df_weather[7295:7300]
# Out:
#           pickup_datetime  tempm  dewptm   hum  wspdi  visi  pressurem  \
# 7295  2016-09-11 22:51:00   10.0     5.6  74.0    4.6  10.0     1013.7
# 7296  2016-09-11 23:51:00    9.4     5.0  74.0    6.9  10.0     1013.9
# 7297  2016-09-12 00:51:00    2.0    -9.0  44.0    6.9   NaN        NaN
# 7298  2016-09-12 01:51:00    1.0    -9.0  48.0    6.9   NaN        NaN
# 7299  2016-09-12 02:51:00    1.0    -9.0  48.0    6.9   NaN        NaN
#
#       precipm     conds  fog  rain  snow  hail  thunder  tornado
# 7295      NaN  Overcast    0     0     0     0        0        0
# 7296      NaN  Overcast    0     0     0     0        0        0
# 7297      NaN   Unknown    0     0     0     0        0        0
# 7298      NaN   Unknown    0     0     0     0        0        0
# 7299      NaN   Unknown    0     0     0     0        0        0

# %%
df_weather.visi.ffill(inplace = True)

# %%
df_weather[7297:7298]
# Out:
#           pickup_datetime  tempm  dewptm   hum  wspdi  visi  pressurem  \
# 7297  2016-09-12 00:51:00    2.0    -9.0  44.0    6.9  10.0        NaN
#
#       precipm    conds  fog  rain  snow  hail  thunder  tornado
# 7297      NaN  Unknown    0     0     0     0        0        0

# %%
df_weather[df_weather.pressurem.isnull() == True].head()
# Out:
#           pickup_datetime  tempm  dewptm   hum  wspdi  visi  pressurem  \
# 2847  2016-04-04 09:00:00   4.15    0.85  79.0    5.8  10.0        NaN
# 3241  2016-04-19 07:00:00  18.05    0.55  31.0    6.9  10.0        NaN
# 3643  2016-05-04 06:00:00  -3.05  -11.95  51.0    6.9  10.0        NaN
# 3922  2016-05-13 00:59:00  14.40    9.40  72.0    4.6  10.0        NaN
# 3923  2016-05-13 02:00:00  14.00   10.00  77.0    4.6  10.0        NaN
#
#       precipm    conds  fog  rain  snow  hail  thunder  tornado
# 2847      NaN  Unknown    0     0     0     0        0        0
# 3241      NaN  Unknown    0     0     0     0        0        0
# 3643      NaN  Unknown    0     0     0     0        0        0
# 3922      NaN  Unknown    0     0     0     0        0        0
# 3923      NaN  Unknown    0     0     0     0        0        0

# %%
df_weather[3240:3245]
# Out:
#           pickup_datetime  tempm  dewptm   hum  wspdi  visi  pressurem  \
# 3240  2016-04-19 06:51:00  17.80    0.00  30.0    6.9  10.0     1013.8
# 3241  2016-04-19 07:00:00  18.05    0.55  31.0    6.9  10.0        NaN
# 3242  2016-04-19 07:51:00  18.30    1.10  32.0    5.8  10.0     1014.5
# 3243  2016-04-19 08:51:00  18.90    4.40  38.0    5.8  10.0     1014.7
# 3244  2016-04-19 10:51:00  20.00    5.00  37.0    9.2  10.0     1015.2
#
#       precipm          conds  fog  rain  snow  hail  thunder  tornado
# 3240      NaN  Mostly Cloudy    0     0     0     0        0        0
# 3241      NaN        Unknown    0     0     0     0        0        0
# 3242      NaN          Clear    0     0     0     0        0        0
# 3243      NaN          Clear    0     0     0     0        0        0
# 3244      NaN  Partly Cloudy    0     0     0     0        0        0

# %%
df_weather.pressurem.ffill(inplace = True)

# %%
df_weather[df_weather.precipm.isnull() == False].head(15)
# Out:
#          pickup_datetime  tempm  dewptm   hum  wspdi  visi  pressurem  \
# 0    2015-12-31 00:15:00    7.8     6.1  89.0    4.6   2.5     1018.2
# 1    2015-12-31 00:42:00    7.8     6.1  89.0    4.6   4.0     1017.8
# 2    2015-12-31 00:51:00    7.8     6.1  89.0    3.5   5.0     1017.0
# 3    2015-12-31 01:51:00    7.2     5.6  90.0    4.6   8.0     1016.5
# 69   2016-01-02 13:51:00   14.4     3.9  49.0    6.9  10.0     1009.1
# 70   2016-01-02 14:51:00   13.3     2.8  49.0    3.5  10.0     1010.0
# 71   2016-01-02 15:51:00   11.7     1.1  48.0    6.9   5.0     1011.3
# 72   2016-01-02 16:51:00   11.1     0.0  47.0    3.5  10.0     1011.6
# 75   2016-01-02 19:51:00   10.0    -2.2  43.0    6.9  10.0     1014.9
# 119  2016-01-04 18:51:00   21.7    13.3  59.0    0.0   8.0      999.0
# 120  2016-01-04 19:51:00   18.9    14.4  75.0    3.5  10.0     1000.1
# 133  2016-01-05 08:51:00    8.9     5.0  77.0    0.0   6.0     1023.9
# 134  2016-01-05 09:51:00    8.3     6.1  86.0    3.5   5.0     1023.2
# 135  2016-01-05 10:48:00    9.0     6.0  82.0    6.9   5.0     1023.6
# 136  2016-01-05 10:51:00    8.9     6.7  86.0    5.8   6.0     1022.7
#
#      precipm             conds  fog  rain  snow  hail  thunder  tornado
# 0        0.5        Light Rain    0     1     0     0        0        0
# 1        0.8          Overcast    0     0     0     0        0        0
# 2        0.8          Overcast    0     0     0     0        0        0
# 3        0.3          Overcast    0     0     0     0        0        0
# 69       0.0          Overcast    0     0     0     0        0        0
# 70       0.0          Overcast    0     0     0     0        0        0
# 71       0.0        Light Rain    0     1     0     0        0        0
# 72       0.3          Overcast    0     0     0     0        0        0
# 75       0.0  Scattered Clouds    0     0     0     0        0        0
# 119      0.0        Light Rain    0     1     0     0        0        0
# 120      0.3     Mostly Cloudy    0     0     0     0        0        0
# 133      0.3        Light Rain    0     1     0     0        0        0
# 134      1.3        Light Rain    0     1     0     0        0        0
# 135      0.8        Light Rain    0     1     0     0        0        0
# 136      0.8        Light Rain    0     1     0     0        0        0

# %% [markdown]
# ### The precipitation readings seem to occur in bunches, so it doesn't make sense to forward fill especially when it occurs so rarely.  Let's simply replace the nan values with 0.  Basically interpreting a nan value reading of precipitation as having no precipitation.

# %%
df_weather.precipm.fillna(0, inplace = True)

# %% [markdown]
# ### All the null values have been filled in

# %% [markdown]
# ## Convert the pickup_datetime string to a datetime object

# %%
df_weather['pickup_datetime'] = pd.to_datetime(df_weather['pickup_datetime'])

# %% [markdown]
# ## Reset the index

# %%
df_weather = df_weather.reset_index(drop = True)

# %%
df_weather.head()
# Out:
#       pickup_datetime  tempm  dewptm   hum  wspdi  visi  pressurem  precipm  \
# 0 2015-12-31 00:15:00    7.8     6.1  89.0    4.6   2.5     1018.2      0.5
# 1 2015-12-31 00:42:00    7.8     6.1  89.0    4.6   4.0     1017.8      0.8
# 2 2015-12-31 00:51:00    7.8     6.1  89.0    3.5   5.0     1017.0      0.8
# 3 2015-12-31 01:51:00    7.2     5.6  90.0    4.6   8.0     1016.5      0.3
# 4 2015-12-31 02:51:00    7.2     5.6  90.0    0.0   8.0     1016.7      0.0
#
#         conds  fog  rain  snow  hail  thunder  tornado
# 0  Light Rain    0     1     0     0        0        0
# 1    Overcast    0     0     0     0        0        0
# 2    Overcast    0     0     0     0        0        0
# 3    Overcast    0     0     0     0        0        0
# 4    Overcast    0     0     0     0        0        0

# %% [markdown]
# ## Explore the data further, looking at the rain/snow for different days

# %%
df_weather_grouped = df_weather.groupby([df_weather.pickup_datetime.dt.month, df_weather.pickup_datetime.dt.day])

# %%
#create a dataframe of how many measurements of each instance were taken
#one column for rain, one for snow, one for nothing
weatherdate = []
raincount = []
snowcount = []
count = []

#iterate through each day as grouped in df_weather_grouped, adding up the instances of rain, snow, and clear
for month, day in df_weather_grouped:
    weatherdate.append(month)
    rain_total = df_weather_grouped.get_group(month).rain.sum()
    snow_total = df_weather_grouped.get_group(month).snow.sum()
    clear_total = len(df_weather_grouped.get_group(month)) - rain_total - snow_total
    
    raincount.append(df_weather_grouped.get_group(month).rain.sum())
    snowcount.append(df_weather_grouped.get_group(month).snow.sum())
    count.append(clear_total)

# %%
df_precip_type = pd.DataFrame({'date':weatherdate,'rain':raincount, 'snow':snowcount, 'clear':count})

# %%
df_precip_type.head()
# Out:
#      date  rain  snow  clear
# 0  (1, 1)     0     0     24
# 1  (1, 2)     1     0     23
# 2  (1, 3)     0     0     26
# 3  (1, 4)     1     0     18
# 4  (1, 5)    11     0     28

# %% [markdown]
# ## Look at the days that it rained

# %%
df_rain = df_precip_type[df_precip_type['rain'] != 0]

# %%
df_rain_sorted = df_rain.sort_values(by = ['rain'], ascending = False)

# %%
df_rain_sorted.head(10)
# Out:
#          date  rain  snow  clear
# 333  (11, 29)    40     0     14
# 54    (2, 24)    36     0     35
# 300  (10, 27)    33     0     16
# 64     (3, 5)    33     0     22
# 319  (11, 15)    28     0     22
# 274   (10, 1)    28     0     18
# 334  (11, 30)    27     0     20
# 210   (7, 29)    26     0     21
# 294  (10, 21)    25     0     38
# 211   (7, 30)    24     0     23

# %% [markdown]
# ## Look at the days that it snowed

# %%
df_snow = df_precip_type[df_precip_type['snow'] != 0]

# %%
df_snow_sorted = df_snow.sort_values(by = ['snow'], ascending = False)

# %%
df_snow_sorted.head(10)
# Out:
#          date  rain  snow  clear
# 22    (1, 23)     0    44      1
# 93     (4, 3)     0    35     21
# 122    (5, 2)     1    24     19
# 80    (3, 21)     0    21     20
# 79    (3, 20)     0    17     20
# 214    (8, 2)     0    15     29
# 351  (12, 17)     5    14     22
# 45    (2, 15)    11    12     23
# 275   (10, 2)     0     8     36
# 16    (1, 17)     0     7     27

# %% [markdown]
# Something here does not look right.  According to this table, it snowed on May 2, and August 2, which does not make sense.  I suspect that the days and months have be reversed for some of the datetimes

# %% [markdown]
# ## Look at the days with neither rain or snow, ie clear

# %%
df_clear = df_precip_type[(df_precip_type['rain'] == 0) & (df_precip_type['snow'] == 0)]

# %%
df_clear_sorted = df_clear.sort_values(by = ['clear'], ascending = False)

# %%
df_clear_sorted.head(10)
# Out:
#          date  rain  snow  clear
# 37     (2, 7)     0     0     71
# 186    (7, 5)     0     0     43
# 69    (3, 10)     0     0     37
# 280   (10, 7)     0     0     35
# 190    (7, 9)     0     0     35
# 125    (5, 5)     0     0     34
# 243   (8, 31)     0     0     33
# 361  (12, 27)     0     0     31
# 301  (10, 28)     0     0     31
# 83    (3, 24)     0     0     31

# %% [markdown]
# Since some of the snow days don't make sense, let's take a look at the daily temperatures for each month to get a better sense of what is going on with our data.

# %%
#plot the daily average temperature for each month
def weatherplot(data):
    #group the data by month
    weather_bymonth = data.groupby(data.pickup_datetime.dt.month)
    plt.figure(figsize = (10,8))
    plt.xticks(range(1,30,1))
    for i in range(1,13):
        #get the month
        tempgroup = weather_bymonth.get_group(i)
        for k in range(1,29):
            #plot the daily mean temperature for the month i
            tempgroup.groupby(tempgroup.pickup_datetime.dt.day).mean().tempm.plot()
    
    plt.grid()
    plt.title('Average Temp for Day by Month')
    plt.xlabel('days')
    plt.ylabel('average tempm')
    plt.show()

# %% [markdown]
# From this plot we can see that something does not look right.  The temperature for each month rises and falls in unison before the 12, then spreads out after the 12 (which is more or less what you would expect the temperatures to look like).

# %%
weatherplot(df_weather)

# %% [markdown]
# This more of less confirms our suspicion that the months and days have been flipped for the days before 12.  In order to fix this, we need to set it so that for entries with a day value of less than 12, the values for day and month switch spots.  So the the day becomes the month, and the month becomes the day

# %%
df_weather['month'] = df_weather.pickup_datetime.dt.month
df_weather['day'] = df_weather.pickup_datetime.dt.day
df_weather['time'] = df_weather.pickup_datetime.dt.time

# %%
#swap the day and month values
for i, k in df_weather.iterrows():
    if df_weather.loc[i,'day'] <= 12:
        temp = df_weather.loc[i,'month']
        df_weather.loc[i,'month'] = df_weather.loc[i,'day']
        df_weather.loc[i,'day'] = temp

# %%
#check one entry to see the swap
df_weather.loc[1038,:]
# Out:
# pickup_datetime    2016-02-05 19:51:00
# tempm                             14.4
# dewptm                            10.6
# hum                                 78
# wspdi                                0
# visi                                 6
# pressurem                       1013.4
# precipm                              0
# conds                             Haze
# fog                                  0
# rain                                 0
# snow                                 0
# hail                                 0
# thunder                              0
# tornado                              0
# month                                5
# day                                  2
# time                          19:51:00
# Name: 1038, dtype: object

# %%
#create a new datetime string out of the correct month and day values
df_weather['new_datetime'] = ['2016-' + str(df_weather.loc[i,'month']) + '-' + str(df_weather.loc[i,'day']) + '-' 
                              + str(df_weather.loc[i,'time']) for i in range(len(df_weather))]

# %%
#check that the new datetime is correct
df_weather.loc[1038,:]
# Out:
# pickup_datetime    2016-02-05 19:51:00
# tempm                             14.4
# dewptm                            10.6
# hum                                 78
# wspdi                                0
# visi                                 6
# pressurem                       1013.4
# precipm                              0
# conds                             Haze
# fog                                  0
# rain                                 0
# snow                                 0
# hail                                 0
# thunder                              0
# tornado                              0
# month                                5
# day                                  2
# time                          19:51:00
# new_datetime         2016-5-2-19:51:00
# Name: 1038, dtype: object

# %%
#convert the new_datetime string into a datetime object
df_weather['new_datetime'] = pd.to_datetime(df_weather['new_datetime'])

# %%
#sort the data by the new_datetime column
df_weather = df_weather.sort_values(by=['new_datetime'], ascending = True)

# %%
#drop the columns we no longer need since we now have the correct datetime
df_weather.drop(columns = ['pickup_datetime', 'month', 'day', 'time'], inplace = True)

# %%
df_weather.reset_index(drop = True, inplace = True)

# %%
df_weather.rename(columns = {'new_datetime':'pickup_datetime'}, inplace = True)

# %%
df_weather.loc[1038,:]
# Out:
# tempm                              7.2
# dewptm                            -6.7
# hum                                 37
# wspdi                              6.9
# visi                                10
# pressurem                       1017.2
# precipm                              0
# conds                            Clear
# fog                                  0
# rain                                 0
# snow                                 0
# hail                                 0
# thunder                              0
# tornado                              0
# pickup_datetime    2016-02-07 15:51:00
# Name: 1038, dtype: object

# %%
df_weather.columns
# Out:
# Index(['tempm', 'dewptm', 'hum', 'wspdi', 'visi', 'pressurem', 'precipm',
#        'conds', 'fog', 'rain', 'snow', 'hail', 'thunder', 'tornado',
#        'pickup_datetime'],
#       dtype='object')

# %%
df_weather = df_weather[['pickup_datetime', 'tempm', 'dewptm', 'hum', 'wspdi', 'visi', 'pressurem', 
                         'precipm', 'conds', 'fog', 'rain', 'snow',
                         'hail', 'thunder', 'tornado']]

# %%
df_weather.head()
# Out:
#       pickup_datetime  tempm  dewptm   hum  wspdi  visi  pressurem  precipm  \
# 0 2016-01-01 00:51:00    5.6    -3.9  51.0    4.6  10.0     1017.9      0.0
# 1 2016-01-01 01:51:00    5.0    -3.9  53.0    3.5  10.0     1017.8      0.0
# 2 2016-01-01 02:51:00    5.0    -3.3  55.0    4.6  10.0     1017.7      0.0
# 3 2016-01-01 03:51:00    5.0    -3.3  55.0    9.2  10.0     1017.7      0.0
# 4 2016-01-01 04:51:00    4.4    -3.3  58.0   10.4  10.0     1017.0      0.0
#
#       conds  fog  rain  snow  hail  thunder  tornado
# 0  Overcast    0     0     0     0        0        0
# 1  Overcast    0     0     0     0        0        0
# 2  Overcast    0     0     0     0        0        0
# 3  Overcast    0     0     0     0        0        0
# 4  Overcast    0     0     0     0        0        0

# %% [markdown]
# With the correct dates now in place, this plot is more or less what we would expect a daily weather plot to look like

# %%
weatherplot(df_weather)

# %% [markdown]
# ## With the correct dates in place, let's look at the rain, snow, and clear days again

# %%
df_weather_grouped = df_weather.groupby([df_weather.pickup_datetime.dt.month, df_weather.pickup_datetime.dt.day])

# %%
#create a dataframe of how many measurements of each instance were taken
#one column for rain, one for snow, one for nothing
weatherdate = []
raincount = []
snowcount = []
count = []

#iterate through each day as grouped in df_weather_grouped, adding up the instances of rain, snow, and clear
for month, day in df_weather_grouped:
    weatherdate.append(month)
    rain_total = df_weather_grouped.get_group(month).rain.sum()
    snow_total = df_weather_grouped.get_group(month).snow.sum()
    clear_total = len(df_weather_grouped.get_group(month)) - rain_total - snow_total
    
    raincount.append(df_weather_grouped.get_group(month).rain.sum())
    snowcount.append(df_weather_grouped.get_group(month).snow.sum())
    count.append(clear_total)

# %%
df_precip_type = pd.DataFrame({'date':weatherdate,'rain':raincount, 'snow':snowcount, 'clear':count})

# %%
df_precip_type.head()
# Out:
#      date  rain  snow  clear
# 0  (1, 1)     0     0     24
# 1  (1, 2)     0     0     24
# 2  (1, 3)     0     0     24
# 3  (1, 4)     0     0     22
# 4  (1, 5)     0     0     22

# %% [markdown]
# ## Look at the days that it rained

# %%
df_rain = df_precip_type[df_precip_type['rain'] != 0]

# %%
df_rain_sorted = df_rain.sort_values(by = ['rain'], ascending = False)

# %%
df_rain_sorted.head()
# Out:
#          date  rain  snow  clear
# 333  (11, 29)    40     0     14
# 54    (2, 24)    36     0     35
# 123    (5, 3)    33     0     22
# 300  (10, 27)    33     0     16
# 9     (1, 10)    28     0     18

# %% [markdown]
# ## Look at the days that it snowed

# %%
df_snow = df_precip_type[df_precip_type['snow'] != 0]

# %%
df_snow_sorted = df_snow.sort_values(by = ['snow'], ascending = False)

# %%
df_snow_sorted.head()
# Out:
#        date  rain  snow  clear
# 22  (1, 23)     0    44      1
# 63   (3, 4)     0    35     21
# 35   (2, 5)     1    24     19
# 80  (3, 21)     0    21     20
# 79  (3, 20)     0    17     20

# %% [markdown]
# ## Look at the days with neither rain or snow, ie clear

# %%
df_clear = df_precip_type[(df_precip_type['rain'] == 0) & (df_precip_type['snow'] == 0)]

# %%
df_clear_sorted = df_clear.sort_values(by = ['clear'], ascending = False)

# %%
df_clear_sorted.head(10)
# Out:
#          date  rain  snow  clear
# 183    (7, 2)     0     0     71
# 127    (5, 7)     0     0     43
# 276   (10, 3)     0     0     37
# 191   (7, 10)     0     0     35
# 250    (9, 7)     0     0     35
# 125    (5, 5)     0     0     34
# 243   (8, 31)     0     0     33
# 83    (3, 24)     0     0     31
# 275   (10, 2)     0     0     31
# 361  (12, 27)     0     0     31

# %%
df_weather.head()
# Out:
#       pickup_datetime  tempm  dewptm   hum  wspdi  visi  pressurem  precipm  \
# 0 2016-01-01 00:51:00    5.6    -3.9  51.0    4.6  10.0     1017.9      0.0
# 1 2016-01-01 01:51:00    5.0    -3.9  53.0    3.5  10.0     1017.8      0.0
# 2 2016-01-01 02:51:00    5.0    -3.3  55.0    4.6  10.0     1017.7      0.0
# 3 2016-01-01 03:51:00    5.0    -3.3  55.0    9.2  10.0     1017.7      0.0
# 4 2016-01-01 04:51:00    4.4    -3.3  58.0   10.4  10.0     1017.0      0.0
#
#       conds  fog  rain  snow  hail  thunder  tornado
# 0  Overcast    0     0     0     0        0        0
# 1  Overcast    0     0     0     0        0        0
# 2  Overcast    0     0     0     0        0        0
# 3  Overcast    0     0     0     0        0        0
# 4  Overcast    0     0     0     0        0        0

# %% [markdown]
# ## Save the dataframe to a csv file

# %%
df_weather.to_csv('weather_edit.csv', index = False)
